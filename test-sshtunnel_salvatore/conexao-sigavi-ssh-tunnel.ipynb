# %%
#!pip install sshtunnel JayDeBeApi paramiko

# %%
import jaydebeapi
import paramiko
import sshtunnel
import pandas as pd

# %%
# Variaveis com os dados de acesso
JS_HOST = '54.233.184.51'
Js_PORT = 22
JS_USER = 'ec2-user'
#JS_PW = 'my-pw'
JS_PKEY = 'datalake-sigavi.pem'
DB_SERVER = '177.52.152.125'
DB_PORT = 1433
DB_NAME = 'SigaviBossaNova'
DB_USER = 'BossaDataLake'
DB_PW = 'Bossa@230203'

# %%
# Percurso onde fica a biblioteca para a conexão com SQL Server JDBC .jar
JARS_PATH = 'mssql-jdbc-12.2.0.jre11.jar'

# %%
# Parametros essenciais para a conexão SSH Tunnel
conn_inputs = {
    'ssh_username': JS_USER,
    'remote_bind_address': (DB_SERVER, DB_PORT)
}

# %%
# Addiciona chave privada, se existe, sobrescreve a password
if JS_PKEY:
    conn_inputs['ssh_pkey'] = paramiko.RSAKey.from_private_key_file(JS_PKEY)

# %%
# Função para executar a query
def execute_query(conn, query):
    cursor = conn.cursor()
    cursor.execute(query)
    return cursor.fetchall()

# %%
with sshtunnel.SSHTunnelForwarder((JS_HOST, Js_PORT), **conn_inputs) as tunnel:
    print('Connected!!')
    # Set the server and port to be the local SSH tunnel values
    server = tunnel.local_bind_address[0]
    port = tunnel.local_bind_address[1]

    conn_string = f"""jdbc:sqlserver://{server}:{port};database={DB_NAME};encrypt=true;trustServerCertificate=true;queryTimeout=45"""

    with jaydebeapi.connect(
        "com.microsoft.sqlserver.jdbc.SQLServerDriver",
        conn_string,
        [DB_USER, DB_PW], JARS_PATH
    ) as conn:
        df = pd.read_sql('SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES', conn)
# Out:
# Connected!!

# %%
df
# Out:
#                           TABLE_NAME
# 0        vwBossaImovelCaracteristica
# 1                      MidiaCampanha
# 2                 PortalTipoDestaque
# 3                 PropostaHierarquia
# 4    PropostaAssinaturaDigitalPessoa
# ..                               ...
# 499                       ImovelZona
# 500                  vwBossaFacExtra
# 501               NotificacaoUsuario
# 502                 tempCaracExcluir
# 503                   MidiaCategoria
#
# [504 rows x 1 columns]

# %%
with sshtunnel.SSHTunnelForwarder((JS_HOST, Js_PORT), **conn_inputs) as tunnel:
    print('Connected!!')
    # Set the server and port to be the local SSH tunnel values
    server = tunnel.local_bind_address[0]
    port = tunnel.local_bind_address[1]

    conn_string = f"""jdbc:sqlserver://{server}:{port};database={DB_NAME};encrypt=true;trustServerCertificate=true;queryTimeout=45"""

    with jaydebeapi.connect(
        "com.microsoft.sqlserver.jdbc.SQLServerDriver",
        conn_string,
        [DB_USER, DB_PW], JARS_PATH
    ) as conn:
        cursor = conn.cursor()
        query = '''SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES'''
        cursor.execute(query)
        cursor.fetchall()

        #query = '''SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES'''
        #results = execute_query(conn, query)
        #results
# Out:
# Connected!!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [35], line 19
#      15 query = '''SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES'''
#      16 #cursor.execute(query)
#      17 #cursor.fetchall()
# ---> 19 df = pd.read_sql('SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES', e)
#      21 #query = '''SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES'''
#      22 #results = execute_query(conn, query)
#      23 #results
#
# File c:\Users\PC\miniconda3\envs\miniconda_0\lib\site-packages\pandas\io\sql.py:564, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     561 pandas_sql = pandasSQL_builder(con)
#     563 if isinstance(pandas_sql, SQLiteDatabase):
# --> 564     return pandas_sql.read_query(
#     565         sql,
#     566         index_col=index_col,
#     567         params=params,
# ...

# %%
df

# %%
results
# Out:
# [('vwBossaImovelCaracteristica',),
#  ('MidiaCampanha',),
#  ('PortalTipoDestaque',),
#  ('PropostaHierarquia',),
#  ('PropostaAssinaturaDigitalPessoa',),
#  ('tempOruloAtivo2007',),
#  ('PortalCaracteristica',),
#  ('MaloteDeParaZona',),
#  ('EstadoCivil',),
#  ('vwBossaImovelPortal',),
#  ('tempImovelZapRio',),
#  ('ImoveisValorAvaliado',),
#  ('SistemaIntegracaoProcesso',),
#  ('TempImovelAlteracaoAVM',),
#  ('MigracaoFacs',),
#  ('ClienteTelefone',),
#  ('PortalTipoDestaqueEmpresa',),
#  ('Imovel',),
#  ('ImovelClick',),
#  ('ImovelSolicitacaoAlteracao',),
#  ('MidiaEmpresa',),
#  ('ImovelBairroComercialBairro',),
#  ('OnlinePreLeadInformacao',),
#  ('EmpreendimentoPortal',),
#  ('OnlineBlackList',),
#  ('Curso',),
#  ('vwPortalFicha',),
#  ('ImovelTipoCaracteristicaAtributo',),
#  ('PropostaHistoricoStatus',),
#  ('SolicitacaoAlteracaoInformacao',),
#  ('ColaboradorCurso',),
#  ('PortalCamposObrigatorios',),
#  ('vwBossaProposta',),
#  ('PortalConfiguracao',),
# ...

# %%
df = pd.DataFrame(results)
df
# Out:
#                                    0
# 0        vwBossaImovelCaracteristica
# 1                      MidiaCampanha
# 2                 PortalTipoDestaque
# 3                 PropostaHierarquia
# 4    PropostaAssinaturaDigitalPessoa
# ..                               ...
# 499                       ImovelZona
# 500                  vwBossaFacExtra
# 501               NotificacaoUsuario
# 502                 tempCaracExcluir
# 503                   MidiaCategoria
#
# [504 rows x 1 columns]

# %%
print(list)
# Out:
# <class 'list'>

# %%
type(results)
# Out:
# list

# %%
        # df = pd.read_sql(conn, query) 
        df = pd.read_sql(conn, query) 
        df
        #print(results)

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

#Mautic (BD MySql)
#Host: private-db3-prd-rds.cyor9py5rdhu.sa-east-1.rds.amazonaws.com
#Database: mkt
#User: datalake
#Password: yb797wdZnigKP!To

cnx = create_engine('mysql+pymysql://datalake:yb797wdZnigKP!To@private-db3-prd-rds.cyor9py5rdhu.sa-east-1.rds.amazonaws.com/mkt')    
cnx
conn = cnx.connect()

result = conn.execute("SELECT * FROM mkt.mktasset_downloads;").fetchall()
df = pd.DataFrame(result)
df
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File c:\Users\PC\miniconda3\envs\miniconda_0\lib\site-packages\pymysql\connections.py:613, in Connection.connect(self, sock)
#     612 try:
# --> 613     sock = socket.create_connection(
#     614         (self.host, self.port), self.connect_timeout, **kwargs
#     615     )
#     616     break
#
# File c:\Users\PC\miniconda3\envs\miniconda_0\lib\socket.py:808, in create_connection(address, timeout, source_address)
#     807 try:
# --> 808     raise err
#     809 finally:
#     810     # Break explicitly a reference cycle
#
# File c:\Users\PC\miniconda3\envs\miniconda_0\lib\socket.py:796, in create_connection(address, timeout, source_address)
#     795     sock.bind(source_address)
# --> 796 sock.connect(sa)
#     797 # Break explicitly a reference cycle
#
# timeout: timed out
#
# ...

# %%
results
# Out:
# [(1, 'Master', True, 4),
#  (2, 'Corretor Usados', True, 4),
#  (3, 'Gerente Usados', True, 4),
#  (4, 'Corretor Online', True, 4),
#  (5, 'Gerente Online', True, 4),
#  (6, 'Operações', True, 3),
#  (7, 'Recepção', True, 4),
#  (39, 'Gerente de Negócios', False, 4),
#  (40, 'Gerente', False, 4),
#  (41, 'Gerente de Negócios', False, 4),
#  (42, 'Diretor de Vendas Usados', True, 4),
#  (43, 'Marketing', True, 4),
#  (44, 'Corretor Plus', False, 4),
#  (45, 'Gerente Usados Plus', False, 4),
#  (46, 'Corretor Lançamentos', True, 4),
#  (47, 'Gerente Lançamentos', True, 4),
#  (48, 'Pós Venda', True, 10),
#  (49, 'Coordenador de Produto', True, 4),
#  (50, 'Diretor de Vendas Plus', False, 4),
#  (51, 'Diretor de Atendimento', False, 4),
#  (52, 'Analista de Atendimento', True, 4),
#  (53, 'Diretor de Vendas Novos', True, 4),
#  (54, 'Financeiro', True, 4),
#  (55, 'CRM', False, 4),
#  (56, 'Recursos Humanos', True, 9),
#  (57, 'Secretaria de Vendas', True, 10),
# ...
