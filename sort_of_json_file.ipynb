# %%
import pandas as pd
import numpy as np
import json



function_lambda = lambda x: x.replace('<h3>','').replace('</h3>','').replace('\n','').replace('\n','').replace('<p>','').replace('</p>','').replace('<a>','').replace('</a>','').replace('<a','').replace('<p class="',' ').replace('"> href="',' ')

# x = lambda a : a + 10
# print(x(5))
# 15

locais = ['ACRE', 'ALAGOAS','AMAPA','AMAZONAS','BAHIA','CEARA','DISTRITO_FEDERAL',
         'ESPIRITO_SANTO', 'GOIAS', 'MARANHAO', 'MATO_GROSSO', 'MATO_GROSSO_DO_SUL',
         'MINAS_GERAIS', 'PARA', 'PARAIBA', 'PARANA', 'PERNAMBUCO', 'PIAUI', 'RIO_DE_JANEIRO',
         'RIO_GRANDE_DO_NORTE', 'RIO_GRANDE_DO_SUL', 'RONDONIA', 'RORAIMA', 'SANTA_CATARINA',
         'SAO_PAULO', 'SERGIPE', 'TOCANTINS']

lista_de_locais = []
new = []
for local in locais:
    #print(local)
    with open('{local}.txt'.format(local=local),'r') as fobj:
        data = json.load(fobj)
    #data['results'][0:len(data['results'])]
    
    for i in data['results']:
        #print(data['results'][0:len(data['results'])])
        Estado = '{local}'.format(local=local)
        Id_1 = i['id']
        Id_2 = i['uf']['id']
        UF = i['uf']['sigla']
        #Descricao = i['uf']['descricao'] # <----- lambda utilizada
        Descricao = function_lambda(i['uf']['descricao'])
        Unidade = i['nomeUnidade']
        Cidade = i['nomeCidade']
        Bairro = i['nomeBairro']
        Rua = i['nomeRua']
        Endereco = i['numeroEndereco']
        Complemento = i['complemento']
        Telefone = i['telefone']
        Email = i['email']
        Cep = i['cep']
        Lat = i['latitude']
        Long = i['longitude']

# {"count":28,"next":null,"previous":null,"results":[{'id': 777, 'uf': {'id': 1, 'sigla': 'AC'}]
# "results":[{'id': 777, 'uf': {'id': 1, 'sigla': 'AC'}]
# data['results'] = {'id': 777, 'uf': {'id': 1, 'sigla': 'AC'}

# i['numeroEndereco']
# 'numeroEndereco': '2710'
    
        x = {'Estado':Estado,'Id_1': Id_1, 'Id_2':Id_2, 'UF':UF, 'Descricao':Descricao, 'Unidade':Unidade,
             'Cidade':Cidade, 'Bairro':Bairro, 'Rua':Rua, 'Endereco':Endereco, 'Complemento':Complemento,
             'Telefone':Telefone, 'Email':Email, 'Cep':Cep, 'Lat':Lat, 'Long':Long}
        
        lista_de_locais.append(x)
    df =  pd.DataFrame(lista_de_locais)
    #df.to_csv('df_all.csv',index=False)
# Out:
#         Estado  Id_1  Id_2  UF  \
# 0         ACRE   777     1  AC
# 1         ACRE   776     1  AC
# 2         ACRE   775     1  AC
# 3         ACRE   774     1  AC
# 4         ACRE   773     1  AC
# ..         ...   ...   ...  ..
# 677  TOCANTINS  1406    27  TO
# 678  TOCANTINS  1405    27  TO
# 679  TOCANTINS  1404    27  TO
# 680  TOCANTINS  1403    27  TO
# 681  TOCANTINS  1402    27  TO
#
#                                              Descricao  \
# 0    Faça sua matrículaO SESI Acre realiza a pré-ma...
# 1    Faça sua matrículaO SESI Acre realiza a pré-ma...
# 2    Faça sua matrículaO SESI Acre realiza a pré-ma...
# 3    Faça sua matrículaO SESI Acre realiza a pré-ma...
# 4    Faça sua matrículaO SESI Acre realiza a pré-ma...
# ..                                                 ...
# 677  Faça sua matrículaPara fazer sua matrícula no ...
# 678  Faça sua matrículaPara fazer sua matrícula no ...
# 679  Faça sua matrículaPara fazer sua matrícula no ...
# 680  Faça sua matrículaPara fazer sua matrícula no ...
# 681  Faça sua matrículaPara fazer sua matrícula no ...
#
#                                                Unidade           Cidade  \
# 0                 Unidade Móvel de Inclusão Digital II       Rio Branco
# 1                         Unidade Móvel Cozinha Brasil       Rio Branco
# 2                    Unidade Móvel de Inclusão Digital       Rio Branco
# 3    Unidade Integrada SESI/SENAI do Juruá Francisc...  Cruzeiro do Sul
# 4                                          Escola SESI       Rio Branco
# ..                                                 ...              ...
# 677               Unidade Móvel de Inclusão Digital II        Araguaína
# 678                    Centro de Treinamento de Palmas           Palmas
# 679      Centro Integrado do Trabalhador Albano Franco           Gurupi
# 680                           Escola SESI de Araguaína        Araguaína
# 681  Serviço Social da Industria do Estado de Tocan...           Palmas
#
#                 Bairro                                 Rua Endereco  \
# 0       Isaura Parente                  Rua Isaura Parente     2710
# 1       Isaura Parente                  Rua Isaura Parente     2710
# 2       Isaura Parente                  Rua Isaura Parente     2710
# 3                 AABB                     Rua Afonso Pena      910
# 4       Isaura Parente                  Rua Isaura Parente     2710
# ..                 ...                                 ...      ...
# 677            Senador                         Dom Emanoel     1347
# 678  Plano Diretor Sul              Quadra ACSE 1 Rua SE 5        2
# 679      Vila Alagoana         Joaquim Batista de Oliveira      161
# 680            Senador                    Av. Dom Emanuel      1347
# 681  Plano Diretor Sul  Quadra ACSE 1 Rua de Pedestre SE 3       26
#
#            Complemento        Telefone                          Email  \
# 0        Complexo SESI  (68) 3901-4467      faleconosco@sesiac.org.br
# 1        Complexo SESI  (68) 3901-4467      faleconosco@sesiac.org.br
# 2        Complexo SESI  (68) 3901-4467      faleconosco@sesiac.org.br
# 3                       (68) 3322-4851      faleconosco@sesiac.org.br
# 4        Complexo SESI  (68) 3901-4467      faleconosco@sesiac.org.br
# ..                 ...             ...                            ...
# 677                     (63) 3229-5700  carmelita@sistemafieto.com.br
# 678  Plano Diretor Sul  (63) 3229-5603   patricia@sistemafieto.com.br
# 679                     (63) 3311-1151      nubia@sistemafieto.com.br
# 680                     (63) 3412-7476  carmelita@sistemafieto.com.br
# 681                                                              None
#
#            Cep          Lat         Long
# 0    69919-015            0            0
# 1    69919-015            0            0
# 2    69919-015            0            0
# 3    69980-000   -7.6274888  -72.6809192
# 4    69919-015   -9.9619758  -67.8384661
# ..         ...          ...          ...
# 677  77813-520            0            0
# 678  77020-018  -10.1864033  -48.3261718
# 679  77403-170  -11.7226767  -49.0836671
# 680  77824-340   -7.1852445  -48.1989368
# 681  77020-016  -10.1864033  -48.3261718
#
# [682 rows x 16 columns]
